# %%
import seaborn as sns
import matplotlib.pyplot as mpl
import pandas as pd

# %%
df = pd.read_csv("../data/IBM_HR_ATTRITION.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
sns.catplot(x="Attrition",y="JobSatisfaction",data=df)

# %%
sns.catplot(x="Attrition",y="JobSatisfaction",kind="box",data=df)

# %%
d = {'Yes': True, 'No': False} #On defini les noms des variables qui vont être transformer en bolean
df['Attrition'] = df['Attrition'].map(d) #On cast la colonne de notre tableau
df.Attrition.sample(5)
# Out:
# 894    False
# 460    False
# 887    False
# 234     True
# 249    False
# Name: Attrition, dtype: bool

# %%
df[((df["TotalWorkingYears"]> 20) & (df["Attrition"])) | ((df["TotalWorkingYears"]> 32) & (df["Attrition"]==0))].describe()
# Out:
#            Age    DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count  40.0000    40.000000         40.000000  40.000000           40.0
# mean   52.3500   669.350000          8.750000   3.350000            1.0
# std     5.3711   399.413066          8.201782   0.948683            0.0
# min    39.0000   102.000000          1.000000   1.000000            1.0
# 25%    51.7500   370.250000          2.000000   3.000000            1.0
# 50%    54.0000   623.500000          7.000000   3.000000            1.0
# 75%    55.2500   804.750000         12.250000   4.000000            1.0
# max    60.0000  1479.000000         26.000000   5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       40.000000                40.000000   40.000000       40.000000
# mean       996.575000                 2.700000   68.300000        2.675000
# std        553.194262                 1.181047   20.592755        0.858965
# ...

# %%
sns.catplot(x="Attrition",y="EducationField",kind="bar",data=df)
